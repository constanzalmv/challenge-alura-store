# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %%
tienda3
# Out:
#                      Producto  Categoría del Producto     Precio  \
# 0            Secadora de ropa       Electrodomésticos  1285100.0
# 1               Mesa de noche                 Muebles   290100.0
# 2           Guitarra acústica  Instrumentos musicales   303500.0
# 3           Balón de voleibol    Deportes y diversión    58800.0
# 4                     Armario                 Muebles   521100.0
# ...                       ...                     ...        ...
# 2354  Dashboards con Power BI                  Libros    26700.0
# 2355  Dashboards con Power BI                  Libros    31800.0
# 2356         Silla de oficina                 Muebles   477100.0
# 2357           Mesa de centro                 Muebles   123100.0
# 2358      Modelado predictivo                  Libros    63400.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 0            66600.0      17/12/2021    Camila Rivera     Santa Marta
# 1            13600.0      10/02/2021    Maria Alfonso            Cali
# 2            17400.0      22/01/2023    Lucas Olivera          Bogotá
# 3             3300.0      22/03/2022      Pedro Gomez    Barranquilla
# 4            25900.0      12/01/2022   Blanca Ramirez          Bogotá
# ...              ...             ...              ...             ...
# 2354          2100.0      21/10/2022  Ángel Rodriguez          Bogotá
# 2355          2200.0      23/06/2022   Blanca Ramirez         Pereira
# 2356         25600.0      19/02/2023    Camila Rivera       Cartagena
# 2357          4700.0      19/09/2021   Blanca Ramirez          Bogotá
# 2358          9400.0      24/05/2022  Mariana Herrera        Medellín
#
#       Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 0                4  Tarjeta de crédito                   4  11.24079 -74.19904
# 1                3  Tarjeta de crédito                   1   3.43722 -76.52250
# 2                5  Tarjeta de crédito                   3   4.60971 -74.08175
# 3                4  Tarjeta de crédito                   6  10.96854 -74.78132
# 4                1  Tarjeta de crédito                   1   4.60971 -74.08175
# ...            ...                 ...                 ...       ...       ...
# 2354             5  Tarjeta de crédito                   1   4.60971 -74.08175
# 2355             5  Tarjeta de crédito                   1   4.81333 -75.69611
# 2356             5  Tarjeta de crédito                   3  10.39972 -75.51444
# 2357             4  Tarjeta de crédito                   8   4.60971 -74.08175
# 2358             5  Tarjeta de crédito                  10   6.25184 -75.56359
#
# [2359 rows x 12 columns]

# %%
tienda4.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_total_tiendas = {}

#creo un dataframe para luego usarlo en gráfico
ingreso_total_tiendas = {
    'Tienda 1': tienda.Precio.sum(),
    'Tienda 2': tienda2.Precio.sum(),
    'Tienda 3': tienda3.Precio.sum(),
    'Tienda 4': tienda4.Precio.sum()
}

df_ingresos = pd.DataFrame.from_dict(ingreso_total_tiendas,
                                   orient='index',
                                   columns=['Ingreso Total'])
df_ingresos = df_ingresos.reset_index()
df_ingresos.columns = ['Tienda', 'Ingreso Total']

print("INGRESOS TOTALES POR TIENDA")
print("="*40)
print(df_ingresos[['Tienda', 'Ingreso Total']].to_string(index=False))
# Out:
# INGRESOS TOTALES POR TIENDA
# ========================================
#   Tienda  Ingreso Total
# Tienda 1   1150880400.0
# Tienda 2   1116343500.0
# Tienda 3   1098019600.0
# Tienda 4   1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
tiendas = [tienda, tienda2, tienda3, tienda4]
resultados = []

for i, df_tienda in enumerate(tiendas, 1):
    agrup = (df_tienda.groupby('Categoría del Producto')['Producto']
             .count()
             .sort_values(ascending=False)
             .head(5)
             .reset_index()) #Volver a crear dataframe
    agrup['Tienda'] = str(i)
    resultados.append(agrup)

categoria_tiendas_agrupadas = pd.concat(resultados, ignore_index=True)
categoria_tiendas_agrupadas

#plt.subplots(2, 2, figsize=(25, 20))



#plt.subplot(2, 2, 1)
#agrup_categorias.plot(kind = 'barh' ,title ='Productos mas vendidos por Categoría en Tienda 1')
#plt.subplot(2, 2, 2)

#agrup_categorias2.plot(kind = 'barh' ,title ='Productos mas vendidos por Categoría en Tienda 2', color = 'purple')
#plt.subplot(2, 2, 3)
#agrup_categorias3.plot(kind = 'barh' ,title ='Productos mas vendidos por Categoría en Tienda 3',color = 'orange')
#plt.subplot(2, 2, 4)
#agrup_categorias4.plot(kind = 'barh' ,title ='Productos mas vendidos por Categoría en Tienda 4',color = 'pink')

#plt.show()
# Out:
#    Categoría del Producto  Producto Tienda
# 0                 Muebles       465      1
# 1            Electrónicos       448      1
# 2                Juguetes       324      1
# 3       Electrodomésticos       312      1
# 4    Deportes y diversión       284      1
# 5                 Muebles       442      2
# 6            Electrónicos       422      2
# 7                Juguetes       313      2
# 8       Electrodomésticos       305      2
# 9    Deportes y diversión       275      2
# 10                Muebles       499      3
# 11           Electrónicos       451      3
# 12               Juguetes       315      3
# 13      Electrodomésticos       278      3
# 14   Deportes y diversión       277      3
# 15                Muebles       480      4
# 16           Electrónicos       451      4
# 17               Juguetes       338      4
# 18   Deportes y diversión       277      4
# 19      Electrodomésticos       254      4

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
#creación de data frame con promedio de tiendas
df_calificaciones = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Calificación Promedio': [
        tienda.Calificación.mean(),
        tienda2.Calificación.mean(),
        tienda3.Calificación.mean(),
        tienda4.Calificación.mean()
    ]
})

# Redondear los valores promedios
df_calificaciones['Calificación Promedio'] = df_calificaciones['Calificación Promedio'].round(2)

df_calificaciones
# Out:
#      Tienda  Calificación Promedio
# 0  Tienda 1                   3.98
# 1  Tienda 2                   4.04
# 2  Tienda 3                   4.05
# 3  Tienda 4                   4.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_calificaciones['Calificación Promedio'].plot(kind='hist', bins=20, title='Calificación Promedio')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_calificaciones.groupby('Tienda').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_calificaciones['Calificación Promedio'].plot(kind='line', figsize=(8, 4), title='Calificación Promedio')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_calificaciones['Tienda'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_calificaciones, x='Calificación Promedio', y='Tienda', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
tiendas = [tienda, tienda2, tienda3, tienda4] #Juntar las tiendas en una lista de DF
resultados = []

#Recorrer las tiendas buscando el mas y menso vendido y agregar la columna Tienda para identificarlas
for i, df_tienda in enumerate(tiendas, 1):
    # Conteo de productos, le agrego la categoría para que quede más claro
    conteo_productos = df_tienda.groupby(['Producto','Categoría del Producto']).size().reset_index(name='Cantidad')

    # Más vendidos por tienda
    mas_vendidos = conteo_productos.nlargest(5, 'Cantidad')
    mas_vendidos['Tienda'] ='Tienda '+ str(i)

    # Solo el primero es "Más Vendido"
    mas_vendidos['Tipo'] = ''
    mas_vendidos.iloc[0, mas_vendidos.columns.get_loc('Tipo')] = 'Más Vendido'

    # Menos vendidos por tienda
    menos_vendidos = conteo_productos.nsmallest(5, 'Cantidad')
    menos_vendidos['Tienda'] ='Tienda '+ str(i)

    # Solo el primero es "Menos Vendido"
    menos_vendidos['Tipo'] = ''
    menos_vendidos.iloc[0, menos_vendidos.columns.get_loc('Tipo')] = 'Menos Vendido'

    resultados.append(mas_vendidos)
    resultados.append(menos_vendidos)

# Combinar los más vendidos y los menos vendidos
productos_vendidos = pd.concat(resultados, ignore_index=True)

# Función para aplicar color al más y menos vendido por tienda
def aplicar_colores_fila(row):
    if row['Tipo'] == 'Más Vendido':
        return ['background-color: #48A13F; color:white; font-weight: bold'] * len(row)  #para darle color a toda la fila (largo de fila)
    elif row['Tipo'] == 'Menos Vendido':
        return ['background-color: #B51636; color: white; font-weight: bold'] * len(row)
    else:
        return [''] * len(row)

# Aplicar estilos
productos_con_colores = productos_vendidos.style.apply(aplicar_colores_fila, axis=1)

print("PRODUCTOS MÁS Y MENOS VENDIDOS POR TIENDA")
print("="*70)
productos_con_colores
# Out:
# PRODUCTOS MÁS Y MENOS VENDIDOS POR TIENDA
# ======================================================================
# <style type="text/css">
# #T_098e4_row0_col0, #T_098e4_row0_col1, #T_098e4_row0_col2, #T_098e4_row0_col3, #T_098e4_row0_col4, #T_098e4_row10_col0, #T_098e4_row10_col1, #T_098e4_row10_col2, #T_098e4_row10_col3, #T_098e4_row10_col4, #T_098e4_row20_col0, #T_098e4_row20_col1, #T_098e4_row20_col2, #T_098e4_row20_col3, #T_098e4_row20_col4, #T_098e4_row30_col0, #T_098e4_row30_col1, #T_098e4_row30_col2, #T_098e4_row30_col3, #T_098e4_row30_col4 {
#   background-color: #48A13F;
#   color: white;
#   font-weight: bold;
# }
# #T_098e4_row5_col0, #T_098e4_row5_col1, #T_098e4_row5_col2, #T_098e4_row5_col3, #T_098e4_row5_col4, #T_098e4_row15_col0, #T_098e4_row15_col1, #T_098e4_row15_col2, #T_098e4_row15_col3, #T_098e4_row15_col4, #T_098e4_row25_col0, #T_098e4_row25_col1, #T_098e4_row25_col2, #T_098e4_row25_col3, #T_098e4_row25_col4, #T_098e4_row35_col0, #T_098e4_row35_col1, #T_098e4_row35_col2, #T_098e4_row35_col3, #T_098e4_row35_col4 {
#   background-color: #B51636;
#   color: white;
#   font-weight: bold;
# }
# </style>
# <table id="T_098e4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_098e4_level0_col0" class="col_heading level0 col0" >Producto</th>
#       <th id="T_098e4_level0_col1" class="col_heading level0 col1" >Categoría del Producto</th>
#       <th id="T_098e4_level0_col2" class="col_heading level0 col2" >Cantidad</th>
#       <th id="T_098e4_level0_col3" class="col_heading level0 col3" >Tienda</th>
#       <th id="T_098e4_level0_col4" class="col_heading level0 col4" >Tipo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_098e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_098e4_row0_col0" class="data row0 col0" >Armario</td>
#       <td id="T_098e4_row0_col1" class="data row0 col1" >Muebles</td>
#       <td id="T_098e4_row0_col2" class="data row0 col2" >60</td>
#       <td id="T_098e4_row0_col3" class="data row0 col3" >Tienda 1</td>
#       <td id="T_098e4_row0_col4" class="data row0 col4" >Más Vendido</td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_098e4_row1_col0" class="data row1 col0" >Microondas</td>
#       <td id="T_098e4_row1_col1" class="data row1 col1" >Electrodomésticos</td>
#       <td id="T_098e4_row1_col2" class="data row1 col2" >60</td>
#       <td id="T_098e4_row1_col3" class="data row1 col3" >Tienda 1</td>
#       <td id="T_098e4_row1_col4" class="data row1 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_098e4_row2_col0" class="data row2 col0" >TV LED UHD 4K</td>
#       <td id="T_098e4_row2_col1" class="data row2 col1" >Electrónicos</td>
#       <td id="T_098e4_row2_col2" class="data row2 col2" >60</td>
#       <td id="T_098e4_row2_col3" class="data row2 col3" >Tienda 1</td>
#       <td id="T_098e4_row2_col4" class="data row2 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_098e4_row3_col0" class="data row3 col0" >Secadora de ropa</td>
#       <td id="T_098e4_row3_col1" class="data row3 col1" >Electrodomésticos</td>
#       <td id="T_098e4_row3_col2" class="data row3 col2" >58</td>
#       <td id="T_098e4_row3_col3" class="data row3 col3" >Tienda 1</td>
#       <td id="T_098e4_row3_col4" class="data row3 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_098e4_row4_col0" class="data row4 col0" >Bloques de construcción</td>
#       <td id="T_098e4_row4_col1" class="data row4 col1" >Juguetes</td>
#       <td id="T_098e4_row4_col2" class="data row4 col2" >56</td>
#       <td id="T_098e4_row4_col3" class="data row4 col3" >Tienda 1</td>
#       <td id="T_098e4_row4_col4" class="data row4 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_098e4_row5_col0" class="data row5 col0" >Auriculares con micrófono</td>
#       <td id="T_098e4_row5_col1" class="data row5 col1" >Electrónicos</td>
#       <td id="T_098e4_row5_col2" class="data row5 col2" >33</td>
#       <td id="T_098e4_row5_col3" class="data row5 col3" >Tienda 1</td>
#       <td id="T_098e4_row5_col4" class="data row5 col4" >Menos Vendido</td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_098e4_row6_col0" class="data row6 col0" >Celular ABXY</td>
#       <td id="T_098e4_row6_col1" class="data row6 col1" >Electrónicos</td>
#       <td id="T_098e4_row6_col2" class="data row6 col2" >33</td>
#       <td id="T_098e4_row6_col3" class="data row6 col3" >Tienda 1</td>
#       <td id="T_098e4_row6_col4" class="data row6 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_098e4_row7_col0" class="data row7 col0" >Olla de presión</td>
#       <td id="T_098e4_row7_col1" class="data row7 col1" >Artículos para el hogar</td>
#       <td id="T_098e4_row7_col2" class="data row7 col2" >35</td>
#       <td id="T_098e4_row7_col3" class="data row7 col3" >Tienda 1</td>
#       <td id="T_098e4_row7_col4" class="data row7 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_098e4_row8_col0" class="data row8 col0" >Pandereta</td>
#       <td id="T_098e4_row8_col1" class="data row8 col1" >Instrumentos musicales</td>
#       <td id="T_098e4_row8_col2" class="data row8 col2" >36</td>
#       <td id="T_098e4_row8_col3" class="data row8 col3" >Tienda 1</td>
#       <td id="T_098e4_row8_col4" class="data row8 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_098e4_row9_col0" class="data row9 col0" >Ciencia de datos con Python</td>
#       <td id="T_098e4_row9_col1" class="data row9 col1" >Libros</td>
#       <td id="T_098e4_row9_col2" class="data row9 col2" >39</td>
#       <td id="T_098e4_row9_col3" class="data row9 col3" >Tienda 1</td>
#       <td id="T_098e4_row9_col4" class="data row9 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_098e4_row10_col0" class="data row10 col0" >Iniciando en programación</td>
#       <td id="T_098e4_row10_col1" class="data row10 col1" >Libros</td>
#       <td id="T_098e4_row10_col2" class="data row10 col2" >65</td>
#       <td id="T_098e4_row10_col3" class="data row10 col3" >Tienda 2</td>
#       <td id="T_098e4_row10_col4" class="data row10 col4" >Más Vendido</td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_098e4_row11_col0" class="data row11 col0" >Microondas</td>
#       <td id="T_098e4_row11_col1" class="data row11 col1" >Electrodomésticos</td>
#       <td id="T_098e4_row11_col2" class="data row11 col2" >62</td>
#       <td id="T_098e4_row11_col3" class="data row11 col3" >Tienda 2</td>
#       <td id="T_098e4_row11_col4" class="data row11 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_098e4_row12_col0" class="data row12 col0" >Batería</td>
#       <td id="T_098e4_row12_col1" class="data row12 col1" >Instrumentos musicales</td>
#       <td id="T_098e4_row12_col2" class="data row12 col2" >61</td>
#       <td id="T_098e4_row12_col3" class="data row12 col3" >Tienda 2</td>
#       <td id="T_098e4_row12_col4" class="data row12 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_098e4_row13_col0" class="data row13 col0" >Guitarra acústica</td>
#       <td id="T_098e4_row13_col1" class="data row13 col1" >Instrumentos musicales</td>
#       <td id="T_098e4_row13_col2" class="data row13 col2" >58</td>
#       <td id="T_098e4_row13_col3" class="data row13 col3" >Tienda 2</td>
#       <td id="T_098e4_row13_col4" class="data row13 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_098e4_level0_row14" class="row_heading level0 row14

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.  Sabiendo que el cliente paga el envío.

# %%
tiendas = [tienda, tienda2, tienda3, tienda4]
nombres_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Calcular promedios por tiendas
promedios_calculo = [df['Costo de envío'].mean().round(2) for df in tiendas]

# Crear DataFrame
promedios_por_tienda = pd.DataFrame({
    'Tienda': nombres_tiendas,
    'Promedio Envio': promedios_calculo
})

print("PROMEDIO DE ENVÍO POR TIENDA")
print("="*70)
color_verde = 'background-color: #48A13F; color:white; font-weight: bold'
color_rojo ='background-color: #B51636; color: white; font-weight: bold'
promedios_por_tienda.style.map(lambda x: color_verde if x == promedios_por_tienda['Promedio Envio'].min() else color_rojo if x == promedios_por_tienda['Promedio Envio'].max() else '',subset=['Promedio Envio'])
# Out:
# PROMEDIO DE ENVÍO POR TIENDA
# ======================================================================
# <style type="text/css">
# #T_e54bd_row0_col1 {
#   background-color: #B51636;
#   color: white;
#   font-weight: bold;
# }
# #T_e54bd_row3_col1 {
#   background-color: #48A13F;
#   color: white;
#   font-weight: bold;
# }
# </style>
# <table id="T_e54bd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e54bd_level0_col0" class="col_heading level0 col0" >Tienda</th>
#       <th id="T_e54bd_level0_col1" class="col_heading level0 col1" >Promedio Envio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e54bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e54bd_row0_col0" class="data row0 col0" >Tienda 1</td>
#       <td id="T_e54bd_row0_col1" class="data row0 col1" >26018.610000</td>
#     </tr>
#     <tr>
#       <th id="T_e54bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e54bd_row1_col0" class="data row1 col0" >Tienda 2</td>
#       <td id="T_e54bd_row1_col1" class="data row1 col1" >25216.240000</td>
#     </tr>
#     <tr>
#       <th id="T_e54bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e54bd_row2_col0" class="data row2 col0" >Tienda 3</td>
#       <td id="T_e54bd_row2_col1" class="data row2 col1" >24805.680000</td>
#     </tr>
#     <tr>
#       <th id="T_e54bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e54bd_row3_col0" class="data row3 col0" >Tienda 4</td>
#       <td id="T_e54bd_row3_col1" class="data row3 col1" >23459.460000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Gráficas

# %%
plt.figure(figsize=(10, 2))

bars = plt.barh(promedios_por_tienda['Tienda'], promedios_por_tienda['Promedio Envio'],
                color=plt.cm.berlin(np.linspace(0,1, len(promedios_por_tienda))),
                linewidth=1)

plt.suptitle('PROMEDIO DE ENVÍO POR TIENDA', fontsize=12, fontweight='bold')
plt.xlabel('Monto Promedio ($)')

for bar in bars:
    width = bar.get_width()
    plt.text(width / 2, bar.get_y() + bar.get_height()/2,
                f'${width:,.0f}', ha='center', va='center',
                color='white', fontweight='bold')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
#df_calificaciones.groupby('Tienda').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
df_calificaciones_ordenado=  df_calificaciones.sort_values('Calificación Promedio', ascending=True)
#bars = plt.barh(df_calificaciones_ordenado['Tienda'], df_calificaciones_ordenado['Calificación Promedio'],
#                color=plt.cm.Spectral(np.linspace(0,1, len(df_calificaciones_ordenado))),
#                linewidth=1)
plt.suptitle('CALIFICACIONES PROMEDIO POR TIENDA', fontsize=12, fontweight='bold')

plt.xlabel('Tienda')
plt.ylabel('Calificación Promedio')
#plt.ticklabel_format(axis='x', style='plain')
#for bar in bars:
#    width = bar.get_width()
#    plt.text(width / 2, bar.get_y() + bar.get_height()/2,
#                f'{width:,.2f}', ha='center', va='center',
#                color='white', fontweight='bold')


plt.plot(df_calificaciones['Tienda'], df_calificaciones['Calificación Promedio'], marker='o', linestyle='--', color="#B427F5", label='Data Series')

plt.show()

# %% [markdown]
# ##PRODUCTOS MÁS VENDIDOS POR TIENDA

# %%
productos_vendidos.sample(10)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))
fig.suptitle('Productos Más vendidos por Tienda')

# Aplanar el array de ejes para iterar sobre cada subplot individualmente
flat_axes = axes.flatten()

for i, tienda_num in enumerate(range(1, 5)):
    flat_axes[i].set_title(f'Tienda {tienda_num}')

# %% [markdown]
# ##DISTRIBUCIÓN DE CATEGORÍAS POR TIENDA

# %%
tiendas = [tienda, tienda2, tienda3, tienda4]
resultados = []

for i, df_tienda in enumerate(tiendas, 1):
    agrup = (df_tienda.groupby('Categoría del Producto')['Producto']
             .count()
             .sort_values(ascending=False)
             .reset_index()) #Volver a crear dataframe
    agrup['Tienda'] = str(i)
    resultados.append(agrup)

categoria_tiendas_agrupadas = pd.concat(resultados, ignore_index=True)

fig, axes = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('DISTRIBUCIÓN DE CATEGORÍAS POR TIENDA', fontsize=16, fontweight='bold')
print(categoria_tiendas_agrupadas)
for i, tienda_num in enumerate(range(1, 5)):
    ax = axes[i//2, i%2]

    datos_tienda = categoria_tiendas_agrupadas[categoria_tiendas_agrupadas['Tienda'] == str(tienda_num)]

    if len(datos_tienda) > 0:
        categorias = datos_tienda['Categoría del Producto']
        cantidades = datos_tienda['Producto']  # Esta columna tiene el conteo

        total = sum(cantidades)

        # Función para mostrar porcentaje y cantidad
        def mostrar_porcentajes_cantidad(pct):
            count = int(round(pct * total / 100.0))
            return f'{pct:.1f}%\n({count})'

        # Crear gráfico de torta
        wedges, texts, autotexts = ax.pie(cantidades,
                                         labels=categorias,
                                         autopct=mostrar_porcentajes_cantidad,
                                         startangle=90,
                                         colors=plt.cm.Set2.colors)

        for autotext in autotexts:
            autotext.set_color('white')
            autotext.set_fontweight('bold')
            autotext.set_fontsize(8)

        for text in texts:
            text.set_fontsize(9)

        ax.set_title(f'Tienda {tienda_num}\nTotal: {total} productos',
                    fontweight='bold', fontsize=11)

    else:
        ax.text(0.5, 0.5, 'No hay datos\npara esta tienda',
                ha='center', va='center', transform=ax.transAxes, fontsize=12)
        ax.set_title(f'Tienda {tienda_num}', fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
#      Categoría del Producto  Producto Tienda
# 0                   Muebles       465      1
# 1              Electrónicos       448      1
# 2                  Juguetes       324      1
# 3         Electrodomésticos       312      1
# 4      Deportes y diversión       284      1
# 5    Instrumentos musicales       182      1
# 6                    Libros       173      1
# 7   Artículos para el hogar       171      1
# 8                   Muebles       442      2
# 9              Electrónicos       422      2
# 10                 Juguetes       313      2
# 11        Electrodomésticos       305      2
# 12     Deportes y diversión       275      2
# 13   Instrumentos musicales       224      2
# 14                   Libros       197      2
# 15  Artículos para el hogar       181      2
# 16                  Muebles       499      3
# 17             Electrónicos       451      3
# 18                 Juguetes       315      3
# 19        Electrodomésticos       278      3
# 20     Deportes y diversión       277      3
# 21                   Libros       185      3
# 22  Artículos para el hogar       177      3
# 23   Instrumentos musicales       177      3
# 24                  Muebles       480      4
# 25             Electrónicos       451      4
# 26                 Juguetes       338      4
# 27     Deportes y diversión       277      4
# 28        Electrodomésticos       254      4
# 29  Artículos para el hogar       201      4
# 30                   Libros       187      4
# 31   Instrumentos musicales       170      4

# %% [markdown]
# ##INGRESOS TOTALES POR TIENDA

# %%
plt.figure(figsize=(12, 4))

df_ordenado = df_ingresos.sort_values('Ingreso Total', ascending=True)

bars = plt.barh(df_ordenado['Tienda'], df_ordenado['Ingreso Total'],
                color=plt.cm.Spectral(np.linspace(0,1, len(df_ordenado))),
                linewidth=1)

plt.title('INGRESOS TOTALES POR TIENDA', fontweight='bold', fontsize=12)
plt.xlabel('Monto ($)')

plt.ticklabel_format(axis='x', style='plain') #Plain para que salgan los montos completos, si no salen como 0.1

for bar in bars:
    width = bar.get_width()
    plt.text(width / 2, bar.get_y() + bar.get_height()/2,
                f'${width:,.0f}', ha='center', va='center',
                color='white', fontweight='bold')

plt.tight_layout()
plt.savefig('ingresos_totales_tiendas.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# #**INFORME FINAL: ANÁLISIS COMPARATIVO DE TIENDAS**
# ####Recomendaciones para Don Juan

# %% [markdown]
# ##1. INTRODUCCIÓN
#
# EL presente análisis tiene como objetivo determinar qué tienda tiene mejores oportunidades de venta para el Señor Juan.
# Se evaluaron un total de cuatro tiendas en donde se consideraron ingresos totales, desempeño de categorías de productos, satisfacción del cliente, productos más y menos vendidos y eficiencia en costos de envío.

# %% [markdown]
# ##2. ANÁLISIS DE RESULTADOS

# %% [markdown]
# ###2.1 Ingresos Totales por Tienda
#
# ![ingresos_totales_tiendas.png](data:image/png;base64,...)
#
# **Hallazgos:**
#
# * **Tienda 1** lidera en ingresos totales, mostrando una capacidad superior de generación de ventas
#
# * **Tienda 2** ocupa el segundo lugar, con un desempeño sólido pero inferior al líder
#
# * Las Tiendas 3 y 4 presentan ingresos significativamente menores

# %% [markdown]
# ###2.2 Desempeño por Categorías de Productos
#
# ![image.png](data:image/png;base64,...)
#
# ####Categorías Más y Menos Populares Por tienda:
#
# * Las tres categorías de productos más populares en todas las tiendas corresponden a **Muebles, Electrónicos y Juguetes**
#
# * Las tres categorías de productos menos populares en todas las tiendas corresponden a **Artículos para el hogar, Libros e Instrumentos musicales.**
#
# * Hay oportunidad de mejora para las categorías de **Electrodomésticos y Deportes y diversión**, para todas las tiendas.

# %% [markdown]
# ###2.3 Satisfacción del Cliente (Calificaciones Promedio)
#
# ![image.png](data:image/png;base64,...)
#
#
# ####Análisis de Experiencia del Cliente:
#
# * **Tienda 3** y **Tienda 2** mantienen calificaciones promedios altas por sobre los 4 puntos de 5, indicando excelente servicio al cliente
#
# * **Tienda 1** tiene el promedio más bajo de todas las tiendas con una calificación bajo los 4 puntos, por lo que presenta oportunidad de mejora en satisfacción al cliente

# %% [markdown]
# ###2.4 Eficiencia en Costos de Envío
#
# ![image.png](data:image/png;base64,...)
#
# ####Eficiencia Operativa:
#
# * **Tienda 4** demuestra mejor gestión logística con costos controlados
#
# * **Tienda 1** presenta oportunidad de mejora en cuanto la logística de envíos, estando por sobre $3000 en comparación a la tienda con mejor rendimiento
#
# Las diferencias en costos impactan directamente en la rentabilidad

# %% [markdown]
# ##**CONCLUSIONES**
#
# De acuerdo a lo analizado, se recomienda al Señor Juan que venda la **Tienda 4**, considerado que a pesar de tener una mayor lógisca en envíos, sigue presentando un monto de ingresos significativamente menor al resto de las otras tiendas, además de no destacar en Servicios de atención al cliente.
#
# Sin embargo se recomienda implementar la logística de envíos realizada en la **Tienda 1**, ya que es la que genera mayores ingresos por sobre el resto de las tiendas, lo que impulsaría aún más la eficiencia de esta tienda.
